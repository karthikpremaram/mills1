# %%
import pickle

# %%
with open("pickle.pkl", "rb") as f:
    a = pickle.load(f)

# %%
a = a['messages']
a
# Out:
# [SystemMessage(content='\nYou are an expert web research assistant. Your goal is to build a detailed company profile by scraping a website and formatting the information into a specific structure. You have access to the following tools:\n\nYour task is to follow a precise workflow to gather and present information.\n\n### Workflow\n\n1.  **Analyze Input**: The user `Input` will contain the URL to start scraping.\n2. \t**create directories**: At starting you must Use the tool to create directories to store scraped and generated data for the first time. Pick main company(single name) or domain name from url and pass to the tool. No special characters in between comapny name(".","@"). Space acceptable.\n3.  **Scrape & Extract**: Use the scrape tools on the initial URL. Analyze the text to find information needed for the `Final Output Template` below.\n4.  **Explore deeper**: If the first page is not enough, find links in the scrapped content with related endpoints. Use the `Web Scraper`
# ...

# %%
print(a[-1].content, end = '')
# Out:
# [{'type': 'text', 'text': "You are the Suntex Marinas AI Assistant, a knowledgeable digital guide for the company's website. Help visitors learn about our boat slips & storage, boat clubs, and boat rentals solutions—purpose-built to make the benefits of being on the water", 'extras': {'signature': '...'}}, ' accessible to anyone.\n\nInteraction Rules\n\t1.\tStart with greeting & details\nBegin with a warm welcome; politely collect name and purpose (e.g., boat slips & storage inquiry, boat club membership, boat rental). Build rapport naturally.\n\t2.\tConfirm intent & respond naturally\nAcknowledge details, confirm purpose, and provide concise answers. For broad queries, summarize briefly and suggest follow-ups like exploring marina solutions, boating platforms, or arranging a call with our experts.\n\t3.\tUse natural flow for lists\nWhen outlining solutions, use soft bullets or short phrases—e.g., boat slips and dry storage, boat club memberships, boat rentals.\n\t4.\tEscalate comple
# ...

# %%
import json

initial = {
    "task_id": 2121,
    "state": "QUEUED",
    "percent": 0,
    "current_step": None,
    "details": None,
    "agent_id": None,
    "error_message": None,
}

agent_name = "karthik"

# Save to a JSON file
filename = f"{agent_name}_task.json"

with open(filename, "w") as f:
    json.dump(initial, f, indent=4)

print(f"Saved to {filename}")
# Out:
# Saved to karthik_task.json
